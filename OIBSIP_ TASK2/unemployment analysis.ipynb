# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
print('complete')
# Out:
# complete

# %%
df1=pd.read_csv('Unemployment in India.csv')
df2=pd.read_csv('Unemployment_Rate_upto_11_2020.csv')
df1.head(20)
# Out:
#             Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0   Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1   Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2   Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3   Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4   Andhra Pradesh   30-09-2019    Monthly                              5.17
# 5   Andhra Pradesh   31-10-2019    Monthly                              3.52
# 6   Andhra Pradesh   30-11-2019    Monthly                              4.12
# 7   Andhra Pradesh   31-12-2019    Monthly                              4.38
# 8   Andhra Pradesh   31-01-2020    Monthly                              4.84
# 9   Andhra Pradesh   29-02-2020    Monthly                              5.91
# 10  Andhra Pradesh   31-03-2020    Monthly                              4.06
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df2.head(20)
# Out:
#             Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0   Andhra Pradesh   31-01-2020          M                              5.48
# 1   Andhra Pradesh   29-02-2020          M                              5.83
# 2   Andhra Pradesh   31-03-2020          M                              5.79
# 3   Andhra Pradesh   30-04-2020          M                             20.51
# 4   Andhra Pradesh   31-05-2020          M                             17.43
# 5   Andhra Pradesh   30-06-2020          M                              3.31
# 6   Andhra Pradesh   31-07-2020          M                              8.34
# 7   Andhra Pradesh   31-08-2020          M                              6.96
# 8   Andhra Pradesh   30-09-2020          M                              6.40
# 9   Andhra Pradesh   31-10-2020          M                              6.59
# 10           Assam   31-01-2020          M                              4.66
# ...

# %%
df1.shape
# Out:
# (768, 7)

# %%
df2.shape
# Out:
# (267, 9)

# %%
#check for null values
df1.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
#remove null vals
df1.dropna(inplace=True)

# %%
df1.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df1['Estimated Unemployment Rate (%)'] = df1.index
df1['Estimated Employed'] = df1.index

# %%
fig, axes = plt.subplots(1,1)

#check which area employs lesss people
#chck which area employs mor
#create chart in each subplot
sns.barplot(data=df1, x='Area', y='Estimated Unemployment Rate (%)')
plt.show()
sns.barplot(data=df1, x='Area', y='Estimated Employed')
plt.show()

# %%
plt.bar(df2['Region'],df2[' Estimated Employed'])
plt.title('Area with the highest employment rate')
plt.ylabel('Estimated employment rate')
plt.xticks(rotation=(90))
plt.xlabel('Region')
plt.show()

#for df2 check the region that employs more and less pple

plt.bar(df2['Region'],df2[' Estimated Unemployment Rate (%)'])
plt.title('Area with the highest unemployment')
plt.ylabel('Estimated unemployment rate')
plt.xticks(rotation=(90))
plt.xlabel('Region')
plt.show()

# %%
sns.pairplot(df1,hue='Area')
# Out:
# C:\Users\Khanyile\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df2,hue='Region')
# Out:
# C:\Users\Khanyile\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area', 'Estimated Unemployment Rate (%)', 'Estimated Employed'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df1[' Date'].value_counts()
# Out:
#  Date
#  31-10-2019    55
#  30-11-2019    55
#  31-05-2019    54
#  30-06-2019    54
#  31-07-2019    54
#  31-08-2019    53
#  31-12-2019    53
#  31-01-2020    53
#  29-02-2020    53
#  30-09-2019    52
#  31-03-2020    52
#  30-04-2020    51
#  31-05-2020    51
#  30-06-2020    50
# Name: count, dtype: int64

# %%
#split the date into individual parts for df1
df1['Day']=df1[' Date'].apply(lambda x:x.split('-')[0])
df1['Day']
# Out:
# 0       31
# 1       30
# 2       31
# 3       31
# 4       30
#       ...
# 749     29
# 750     31
# 751     30
# 752     31
# 753     30
# Name: Day, Length: 740, dtype: object

# %%
df1['Month']=df1[' Date'].apply(lambda x:x.split('-')[1])
df1['Month']
# Out:
# 0      05
# 1      06
# 2      07
# 3      08
# 4      09
#        ..
# 749    02
# 750    03
# 751    04
# 752    05
# 753    06
# Name: Month, Length: 740, dtype: object

# %%
df1['Year']=df1[' Date'].apply(lambda x:x.split('-')[2])
df1['Year']
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 749    2020
# 750    2020
# 751    2020
# 752    2020
# 753    2020
# Name: Year, Length: 740, dtype: object

# %%
df1.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area  \
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural
#
#    Estimated Unemployment Rate (%)  Estimated Employed  Day Month  Year
# ...

# %%
#fix the new data
df1.Month.astype('int')
df1.Day.astype('int')
df1.Year.astype('int')
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 749    2020
# 750    2020
# 751    2020
# 752    2020
# 753    2020
# Name: Year, Length: 740, dtype: int32

# %%
df1[' Estimated Unemployment Rate (%)'].dtype
# Out:
# dtype('float64')

# %%
#find the number of people that are unemployed
#Estimated Unemployment Rate (%)* Estimated Employed=  unemployed pple
df1['Unemployed People']=df1[' Estimated Unemployment Rate (%)']*df1[' Estimated Employed'].round(0)
df1['Unemployed People'].astype(int)
# Out:
# 0       43796857
# 1       35855437
# 2       45325151
# 3       40788500
# 4       63367459
#          ...
# 749     82077318
# 750     72076720
# 751    145350653
# 752    140646543
# 753     89616859
# Name: Unemployed People, Length: 740, dtype: int32

# %%
#plot the month with the highest unemployment and employment
plt.bar(df1['Month'],df1['Unemployed People'])
plt.title('Month with the highest unemployment')
plt.ylabel('Estimated employment rate')
plt.xlabel('Month')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(df1['Month'],df1[ ' Estimated Employed'])
plt.title('Month with the highest estimated employment')
plt.ylabel('Estimated employment rate') 
plt.xlabel('Month')
plt.show()

# %%
#find the year with highest and lowest  employment rate
plt.bar(df1['Year'],df1['Unemployed People'])
plt.title('Year with the highest unemployment')
plt.ylabel('Estimated unemployment rate') 
plt.xlabel('Year')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(df1['Year'],df1[ ' Estimated Employed'])
plt.title('Year with the highest employment')
plt.ylabel('Estimated employment rate')
plt.xticks() 
plt.xlabel('Year')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df2.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df2['Day']=df2[' Date'].apply(lambda x:x.split('-')[0])
df2['Day'].astype(int)
# Out:
# 0      31
# 1      29
# 2      31
# 3      30
# 4      31
#        ..
# 262    30
# 263    31
# 264    31
# 265    30
# 266    31
# Name: Day, Length: 267, dtype: int32

# %%
df2['Month']=df2[' Date'].apply(lambda x:x.split('-')[1])
df2['Month'].astype(int)
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 262     6
# 263     7
# 264     8
# 265     9
# 266    10
# Name: Month, Length: 267, dtype: int32

# %%
df2['Year']=df2[' Date'].apply(lambda x:x.split('-')[2])
df2['Year'].astype(int)
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 262    2020
# 263    2020
# 264    2020
# 265    2020
# 266    2020
# Name: Year, Length: 267, dtype: int32

# %%
df2['Unemployed People']=df2[' Estimated Unemployment Rate (%)']*df1[' Estimated Employed'].round(0)
df2.head(10)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
# 5  Andhra Pradesh   30-06-2020          M                              3.31
# 6  Andhra Pradesh   31-07-2020          M                              8.34
# 7  Andhra Pradesh   31-08-2020          M                              6.96
# 8  Andhra Pradesh   30-09-2020          M                              6.40
# 9  Andhra Pradesh   31-10-2020          M                              6.59
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# ...

# %%
plt.bar(df2['Month'],df2['Unemployed People'])
plt.title('Month with the highest unemployment')
plt.ylabel('Estimated unemployment rate')
plt.xlabel('Month')
plt.show()

# %%
plt.bar(df2['Month'],df2[ ' Estimated Employed'])
plt.title('Month with the highest employment')
plt.ylabel('Estimated employment rate')
plt.xlabel('Month')
plt.show()

# %%
#unemployment and employment yearly for df2 are not calculated because there is only one yr(2020)

# %%
df1['Unemployed People'].astype(int)
# Out:
# 0       43796857
# 1       35855437
# 2       45325151
# 3       40788500
# 4       63367459
#          ...
# 749     82077318
# 750     72076720
# 751    145350653
# 752    140646543
# 753     89616859
# Name: Unemployed People, Length: 740, dtype: int32

# %%
df1[' Estimated Employed'].astype(int)
# Out:
# 0      11999139
# 1      11755881
# 2      12086707
# 3      12285693
# 4      12256762
#          ...
# 749    10871168
# 750    10806105
# 751     9299466
# 752     9240903
# 753     9088931
# Name:  Estimated Employed, Length: 740, dtype: int32

# %%
#find the unemployment rate for df1
df1_total=df1[' Estimated Employed'].sum()+ df1['Unemployed People'].sum()
df1_total.round(0)
# Out:
# 53894138330.0

# %%
df1_ttl=df1['Unemployed People'].sum()
df1_ttl.round(0)
# Out:
# 48562837911.0

# %%
#Total unemployment rate for df1
df1_rate=(df1_ttl/df1_total)*100
df1_rate.round(0)
# Out:
# 90.0

# %%
#find the unemployment rate for df2
df2_total=df2[' Estimated Employed'].sum()+ df2['Unemployed People'].sum()
df2_total.round(0)
# Out:
# 30090301029.0

# %%
df2_ttl=df2['Unemployed People'].sum()
df2_ttl.round(0)
# Out:
# 26362418801.0

# %%
df2_rate=(df2_ttl/df2_total)*100
df2_rate.round(0)
# Out:
# 88.0
